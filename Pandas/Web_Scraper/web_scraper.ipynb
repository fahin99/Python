# %%
import pandas as pd

# %% [markdown]
# ### 1. Read a .csv from an url w Pandas
# #### Target site: https://www.football-data.co.uk/data.php

# %%
# reading the csv file
url='https://www.football-data.co.uk/mmz4281/2526/E0.csv'
df_epl=pd.read_csv(url)

# %%
# FTHG & FTAG terms are confusing, while they just mean 
# final time home goals and aways goals
df_epl.rename(columns={'FTHG':'home_goals', 
                          'FTAG':'away_goals'}, inplace=True)
df_epl
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  home_goals  \
# 0    E0  15/08/2025  20:00      Liverpool  Bournemouth           4
# 1    E0  16/08/2025  12:30    Aston Villa    Newcastle           0
# 2    E0  16/08/2025  15:00       Brighton       Fulham           1
# 3    E0  16/08/2025  15:00     Sunderland     West Ham           3
# 4    E0  16/08/2025  15:00      Tottenham      Burnley           3
# ..   ..         ...    ...            ...          ...         ...
# 375  E0  24/05/2026  16:00       Man City  Aston Villa           1
# 376  E0  24/05/2026  16:00  Nott'm Forest  Bournemouth           1
# 377  E0  24/05/2026  16:00     Sunderland      Chelsea           2
# 378  E0  24/05/2026  16:00      Tottenham      Everton           1
# 379  E0  24/05/2026  16:00       West Ham        Leeds           3
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0             2   H     1     0  ...     2.03     1.78   2.07   1.85     2.03
# ...

# %% [markdown]
# ### 2. Working with multiple .csv files

# %%
# now we read multiple csvs and add them to a list
# for that we need a root url
root="https://www.football-data.co.uk/mmz4281/"

leagues=['E0', 'E1', 'E2']

# %%
# now we loop thru the legues array and read the corresponding csvs
frames=[]
for league in leagues:
    df=pd.read_csv(root+'2526/'+league+'.csv')
    frames.append(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 # now we loop thru the legues array and read the corresponding csvs
#       2 frames=[]
#       3 for league in leagues:
# ----> 4     df=pd.read_csv(root+'2526/'+league+'.csv')
#       5     frames.append(df)
#
# ...

# %%
#check the length of "frames"
len(frames)
# Out:
# 3

# %%
frames[1]
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E1  08/08/2025  20:00      Birmingham        Ipswich     1     1   D
# 1    E1  09/08/2025  12:30        Charlton        Watford     1     0   H
# 2    E1  09/08/2025  12:30        Coventry           Hull     0     0   D
# 3    E1  09/08/2025  12:30     Southampton        Wrexham     2     1   H
# 4    E1  09/08/2025  15:00   Middlesbrough        Swansea     1     0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 547  E1  02/05/2026  12:30         Preston    Southampton     1     3   A
# 548  E1  02/05/2026  12:30  Sheffield Weds      West Brom     2     1   H
# 549  E1  02/05/2026  12:30         Swansea       Charlton     3     1   H
# 550  E1  02/05/2026  12:30         Watford       Coventry     0     4   A
# 551  E1  02/05/2026  12:30         Wrexham  Middlesbrough     2     2   D
#
#      HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# ...

# %%
for df in frames:
    df.rename(columns={'FTHG':'home_goals', 
                          'FTAG':'away_goals'}, inplace=True)

frames[1]
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  home_goals  \
# 0    E1  08/08/2025  20:00      Birmingham        Ipswich           1
# 1    E1  09/08/2025  12:30        Charlton        Watford           1
# 2    E1  09/08/2025  12:30        Coventry           Hull           0
# 3    E1  09/08/2025  12:30     Southampton        Wrexham           2
# 4    E1  09/08/2025  15:00   Middlesbrough        Swansea           1
# ..   ..         ...    ...             ...            ...         ...
# 547  E1  02/05/2026  12:30         Preston    Southampton           1
# 548  E1  02/05/2026  12:30  Sheffield Weds      West Brom           2
# 549  E1  02/05/2026  12:30         Swansea       Charlton           3
# 550  E1  02/05/2026  12:30         Watford       Coventry           0
# 551  E1  02/05/2026  12:30         Wrexham  Middlesbrough           2
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...

# %% [markdown]
# #### Multiple seasons

# %%
frames=[]
for league in leagues:
    for season in range(20,26):
        df=pd.read_csv(root+str(season)+str(season+1)+'/'+league+'.csv', encoding='unicode_escape')
        df['season']=season
        frames.append(df)

# %%
len(frames)
# Out:
# 18

# %% [markdown]
# ### 3. Organize all the data in a  dictionary

# %%
dict_countries={'La Liga':'SP1', 'Spanish Segunda Div':'SP2',
                'Bundesliga':'D1',
                'EPL':'E0', 'Eng League 1':'E1'}

# %%
dict_historical_data={}

# looping thru keys and creating list of leagues

frames=[]

for league in dict_countries:
    for season in range(20,26):
        df=pd.read_csv(root+str(season)+str(season+1)+'/'+dict_countries[league]+'.csv', encoding='unicode_escape')
        df.insert(1, 'Season', season)
        frames.append(df)
    # here we create frame for each league and add it to the dictionary with the league name as key
    df_net=pd.concat(frames)
    dict_historical_data[league]=df_net
# Out:
# C:\Users\abirl\AppData\Local\Temp\ipykernel_16756\1232805658.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(1, 'Season', season)

# %%
dict_historical_data['La Liga']
# Out:
#      Div  Season        Date   Time     HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 0    SP1      20  12/09/2020  15:00        Eibar       Celta     0     0   D
# 1    SP1      20  12/09/2020  17:30      Granada  Ath Bilbao     2     0   H
# 2    SP1      20  12/09/2020  20:00        Cadiz     Osasuna     0     2   A
# 3    SP1      20  13/09/2020  13:00       Alaves       Betis     0     1   A
# 4    SP1      20  13/09/2020  15:00   Valladolid    Sociedad     1     1   D
# ..   ...     ...         ...    ...          ...         ...   ...   ...  ..
# 375  NaN      25  23/05/2026  20:00       Girona       Elche     1     1   D
# 376  NaN      25  23/05/2026  20:00     Mallorca      Oviedo     3     0   H
# 377  NaN      25  23/05/2026  20:00  Real Madrid  Ath Bilbao     4     2   H
# 378  NaN      25  23/05/2026  20:00     Valencia   Barcelona     3     1   H
# 379  NaN      25  24/05/2026  20:00   Villarreal  Ath Madrid     5     1   H
#
# ...

# %% [markdown]
# ### Filter dataframe based on a condition

# %%
df_epl[df_epl['HomeTeam']=="Man City"]
# Out:
#     Div        Date   Time  HomeTeam        AwayTeam  home_goals  away_goals  \
# 11   E0  23/08/2025  12:30  Man City       Tottenham           0           2
# 39   E0  14/09/2025  16:30  Man City      Man United           3           0
# 54   E0  27/09/2025  15:00  Man City         Burnley           5           1
# 74   E0  18/10/2025  15:00  Man City         Everton           2           0
# 98   E0  02/11/2025  16:30  Man City     Bournemouth           3           1
# 109  E0  09/11/2025  16:30  Man City       Liverpool           3           0
# 121  E0  29/11/2025  15:00  Man City           Leeds           3           2
# 143  E0  06/12/2025  15:00  Man City      Sunderland           3           0
# 163  E0  20/12/2025  15:00  Man City        West Ham           3           0
# 199  E0  04/01/2026  17:30  Man City         Chelsea           1           1
# 206  E0  07/01/2026  19:30  Man City        Brighton           1           1
# ...

# %%
len(df_epl[df_epl['HomeTeam']=="Man City"])
# Out:
# 19

# %%
# we can also find the number of home matches played by
# man city, and chelsea like this:-

df_epl[(df_epl['HomeTeam']=="Man City") | (df_epl['HomeTeam']=="Chelsea")].value_counts('HomeTeam')
# Out:
# HomeTeam
# Chelsea     19
# Man City    19
# Name: count, dtype: int64

# %% [markdown]
# ### Create column based on 1 conditions: np.where()

# %%
import numpy as np

# create an array based on AvgCAHH greater than 1.92

np.where(df_epl['AvgCAHH']>=1.92, 'High', 'Low')
# Out:
# array(['High', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low',
#        'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'High', 'High',
#        'High', 'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low',
#        'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low',
#        'High', 'High', 'Low', 'High', 'Low', 'Low', 'High', 'Low', 'Low',
#        'High', 'Low', 'High', 'Low', 'High', 'Low', 'High', 'High', 'Low',
#        'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'Low',
#        'Low', 'Low', 'High', 'Low', 'Low', 'High', 'Low', 'Low', 'Low',
#        'High', 'Low', 'High', 'High', 'High', 'Low', 'Low', 'Low', 'High',
#        'Low', 'High', 'High', 'High', 'Low', 'High', 'High', 'Low', 'Low',
#        'Low', 'Low', 'High', 'High', 'High', 'Low', 'High', 'Low', 'Low',
#        'Low', 'Low', 'High', 'Low', 'High', 'High', 'High', 'High',
#        'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 'Low',
# ...

# %%
# set it to a new column
df_epl['AvgCAHH_tier']=np.where(df_epl['AvgCAHH']>=1.92, 'High', 'Low')

df_epl
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  home_goals  \
# 0    E0  15/08/2025  20:00      Liverpool  Bournemouth           4
# 1    E0  16/08/2025  12:30    Aston Villa    Newcastle           0
# 2    E0  16/08/2025  15:00       Brighton       Fulham           1
# 3    E0  16/08/2025  15:00     Sunderland     West Ham           3
# 4    E0  16/08/2025  15:00      Tottenham      Burnley           3
# ..   ..         ...    ...            ...          ...         ...
# 375  E0  24/05/2026  16:00       Man City  Aston Villa           1
# 376  E0  24/05/2026  16:00  Nott'm Forest  Bournemouth           1
# 377  E0  24/05/2026  16:00     Sunderland      Chelsea           2
# 378  E0  24/05/2026  16:00      Tottenham      Everton           1
# 379  E0  24/05/2026  16:00       West Ham        Leeds           3
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHA PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0             2   H     1     0  ...     1.78  2.07   1.85     2.03     1.88
# ...

# %%
df_epl['AvgCAHH_tier'].value_counts()
# Out:
# AvgCAHH_tier
# Low     252
# High    128
# Name: count, dtype: int64

# %% [markdown]
# ### Creating column from more than 2 choices: np.select()

# %%
conditions=[
    df_epl['AvgCAHH']>=2,
    (df_epl['AvgCAHH']<2) & (df_epl['AvgCAHH']>=1.8),
    df_epl['AvgCAHH']<1.8
]

values= ['High', 'Mid', 'Low']

# %%
df_epl['AvgCAHH_score']= np.select(conditions, values, default='Unknown')
# Out:
# C:\Users\abirl\AppData\Local\Temp\ipykernel_8436\1867696189.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_epl['AvgCAHH_score']= np.select(conditions, values, default='Unknown')

# %% [markdown]
# #### isin: single filtering

# %%
df_epl[df_epl['HomeTeam'].isin(['Man City', 'Chelsea'])].value_counts('HomeTeam')
# Out:
# HomeTeam
# Chelsea     19
# Man City    19
# Name: count, dtype: int64

# %% [markdown]
# ### Find duplicates

# %%
dupli = df_epl.duplicated(['HomeTeam', 'AwayTeam', 'Date'], keep='first')

# show the duplicate rows after the first occurrence
# change keep='first' to keep=False if you want every matching row marked as duplicate
df_epl[dupli].sort_values(['HomeTeam', 'Date'])
# Out:
# Empty DataFrame
# Columns: [Div, Date, Time, HomeTeam, AwayTeam, home_goals, away_goals, FTR, HTHG, HTAG, HTR, Referee, HS, AS, HST, AST, HF, AF, HC, AC, HY, AY, HR, AR, B365H, B365D, B365A, BFDH, BFDD, BFDA, BMGMH, BMGMD, BMGMA, BVH, BVD, BVA, BWH, BWD, BWA, CLH, CLD, CLA, LBH, LBD, LBA, PSH, PSD, PSA, MaxH, MaxD, MaxA, AvgH, AvgD, AvgA, BFEH, BFED, BFEA, B365>2.5, B365<2.5, P>2.5, P<2.5, Max>2.5, Max<2.5, Avg>2.5, Avg<2.5, BFE>2.5, BFE<2.5, AHh, B365AHH, B365AHA, PAHH, PAHA, MaxAHH, MaxAHA, AvgAHH, AvgAHA, BFEAHH, BFEAHA, B365CH, B365CD, B365CA, BFDCH, BFDCD, BFDCA, BMGMCH, BMGMCD, BMGMCA, BVCH, BVCD, BVCA, BWCH, BWCD, BWCA, CLCH, CLCD, CLCA, LBCH, LBCD, LBCA, PSCH, ...]
# Index: []
#
# [0 rows x 134 columns]

# %%
dupliNot=df_epl.duplicated(['HomeTeam'], keep='first')
df_epl[~dupliNot].sort_values(['HomeTeam', 'Date'])
# Out:
#    Div        Date   Time        HomeTeam        AwayTeam  home_goals  \
# 15  E0  23/08/2025  17:30         Arsenal           Leeds           5
# 1   E0  16/08/2025  12:30     Aston Villa       Newcastle           0
# 12  E0  23/08/2025  15:00     Bournemouth          Wolves           1
# 13  E0  23/08/2025  15:00       Brentford     Aston Villa           1
# 2   E0  16/08/2025  15:00        Brighton          Fulham           1
# 14  E0  23/08/2025  15:00         Burnley      Sunderland           2
# 6   E0  17/08/2025  14:00         Chelsea  Crystal Palace           0
# 16  E0  24/08/2025  14:00  Crystal Palace   Nott'm Forest           1
# 17  E0  24/08/2025  14:00         Everton        Brighton           2
# 18  E0  24/08/2025  16:30          Fulham      Man United           1
# 9   E0  18/08/2025  20:00           Leeds         Everton           1
# 0   E0  15/08/2025  20:00       Liverpool     Bournemouth           4
# ...

# %%
df_epl.drop_duplicates(['HomeTeam', 'AwayTeam', 'Date'])
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  home_goals  \
# 0    E0  15/08/2025  20:00      Liverpool  Bournemouth           4
# 1    E0  16/08/2025  12:30    Aston Villa    Newcastle           0
# 2    E0  16/08/2025  15:00       Brighton       Fulham           1
# 3    E0  16/08/2025  15:00     Sunderland     West Ham           3
# 4    E0  16/08/2025  15:00      Tottenham      Burnley           3
# ..   ..         ...    ...            ...          ...         ...
# 375  E0  24/05/2026  16:00       Man City  Aston Villa           1
# 376  E0  24/05/2026  16:00  Nott'm Forest  Bournemouth           1
# 377  E0  24/05/2026  16:00     Sunderland      Chelsea           2
# 378  E0  24/05/2026  16:00      Tottenham      Everton           1
# 379  E0  24/05/2026  16:00       West Ham        Leeds           3
#
#      away_goals FTR  HTHG  HTAG  ... PCAHH PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0             2   H     1     0  ...  2.07  1.85     2.03     1.88     1.94
# ...
